# %% [markdown]
# # Teste de hipótese T para média salárial

# %% [markdown]
# ## Hipótese proposta:H0 o Salário de um engenheiro no Brasil é de R 7.331,00

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# amostra obtida via pesquisa

df = pd.read_excel('Salários Eng.xlsx')
df
# Out:
#    Entrevistado  Salário Informado
# 0            x1               6800
# 1            x2               6800
# 2            x3               6800
# 3            x4               6800
# 4            x5               6800
# 5            x6               6800
# 6            x7               6800
# 7            x8               6800
# 8            x9               6800
# 9           x10               6800
# 10          x11               6800
# 11          x12               6800
# 12          x13               6800
# 13          x14               6800
# 14          x15               6800
# 15          x16               6800
# 16          x17               6800
# 17          x18               6800
# 18          x19               6800
# 19          x20               7200
# 20          x21               7200
# 21          x22               7200
# 22          x23               7200
# 23          x24               7200
# 24          x25               7200
# 25          x26               6254
# ...

# %%
df['Salário Informado'] = df['Salário Informado'].astype(float)

# %% [markdown]
# # Verificando a distribuição dos dados

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.histplot(df['Salário Informado'], kde=True)
ax.set_title('Histograma', fontsize=15)

plt.show()

# %% [markdown]
# ## Obtendo as estatísticas da amostra

# %%
salario_describe = df['Salário Informado'].describe().round(2).reset_index()
salario_describe.columns = ['Estatística', 'Salário']
salario_describe
# Out:
#   Estatística   Salário
# 0       count     51.00
# 1        mean   7573.18
# 2         std   1303.52
# 3         min   6254.00
# 4         25%   6800.00
# 5         50%   7200.00
# 6         75%   8011.00
# 7         max  11800.00

# %% [markdown]
# ### Aplicando o teste T-score para a Negar a hipótese

# %%
stat, p = stats.ttest_1samp(df['Salário Informado'], popmean=7331)

print('Estatística de teste: %.2f' %(stat.round(2)))
print('P-Valor: %.2f' %(p.round(2)))

print('\nResultado:')
if p > 0.05:
    print('A média salarial pode ser R$ 7.331,00')
else:
    print('A média salarial pode ser maior que R$ 7.331,00')
# Out:
# Estatística de teste: 1.33
# P-Valor: 0.19
#
# Resultado:
# A média salarial pode ser R$ 7.331,00

# %%
# Estatística de teste positiva +, quer dizer que minha média amostral é maior qua a média de teste
# logo o P valor fica para a direita neste caso

# %% [markdown]
# ### Neste caso considerando um grau de significancia alpha = 0,05
#
# ### A hipótese proposta não pode ser rejeitada
#
# ### Rejeita se p-Valor <= 0,01 (casos mais sérios)
#
# ### ou Rejeita se p-Valor <= 0,05

# %% [markdown]
# # Erro tipo I = alpha O algoritmo aceita a hiótese nula, mas ela é falsa
#
# # Erro tipo II = beta : O algoritmo nega a hipótese nula que é verdadeira
