# %% [markdown]
# # Prevendo preço de carros

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('carprices.csv')

# %%
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
df.dtypes
# Out:
# Car Model        object
# Mileage           int64
# Sell Price($)     int64
# Age(yrs)          int64
# dtype: object

# %%
df.shape
# Out:
# (13, 4)

# %%
df.isnull().values.any()
# Out:
# False

# %%
# Verificando se existe uma correlação

def plot_corr(df, size=10):
    corr = df.corr()
    fig, ax = plt.subplots(figsize= (size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)

# %%
plot_corr(df)

# %%
df.corr()
# Out:
#                 Mileage  Sell Price($)  Age(yrs)
# Mileage        1.000000      -0.927116  0.993452
# Sell Price($) -0.927116       1.000000 -0.921741
# Age(yrs)       0.993452      -0.921741  1.000000

# %%
# vamos organizar as variáveis que são categóricas - marcas

df_dummies = pd.get_dummies(df['Car Model'])

# %%
df_dummies
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
df_numerical = df[['Mileage', 'Age(yrs)', 'Sell Price($)']]
df_numerical
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          29400
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          20000
# 11    79000         7          21000
# 12    59000         5          33000

# %%
df_new = pd.concat([df_dummies, df_numerical], axis=1)

# %%
df_new
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class  Mileage  Age(yrs)  Sell Price($)
# 0         0       1                      0    69000         6          18000
# 1         0       1                      0    35000         3          34000
# 2         0       1                      0    57000         5          26100
# 3         0       1                      0    22500         2          40000
# 4         0       1                      0    46000         4          31500
# 5         1       0                      0    59000         5          29400
# 6         1       0                      0    52000         5          32000
# 7         1       0                      0    72000         6          19300
# 8         1       0                      0    91000         8          12000
# 9         0       0                      1    67000         6          22000
# 10        0       0                      1    83000         7          20000
# ...

# %%
df_new.dtypes
# Out:
# Audi A5                  uint8
# BMW X5                   uint8
# Mercedez Benz C class    uint8
# Mileage                  int64
# Age(yrs)                 int64
# Sell Price($)            int64
# dtype: object

# %%
plot_corr(df_new)

# %%
df_new.corr()
# Out:
#                         Audi A5    BMW X5  Mercedez Benz C class   Mileage  \
# Audi A5                1.000000 -0.527046              -0.444444  0.275426
# BMW X5                -0.527046  1.000000              -0.527046 -0.642673
# Mercedez Benz C class -0.444444 -0.527046               1.000000  0.402011
# Mileage                0.275426 -0.642673               0.402011  1.000000
# Age(yrs)               0.290701 -0.651155               0.395676  0.993452
# Sell Price($)         -0.246918  0.400640              -0.175394 -0.927116
#
#                        Age(yrs)  Sell Price($)
# Audi A5                0.290701      -0.246918
# BMW X5                -0.651155       0.400640
# Mercedez Benz C class  0.395676      -0.175394
# Mileage                0.993452      -0.927116
# Age(yrs)               1.000000      -0.921741
# Sell Price($)         -0.921741       1.000000

# %%
# agora percebi que o modelo inflencia - moderadamente - no preço de venda

# com isso vou definir as variáveis do processo

features = ['Audi A5', 'BMW X5', 'Mercedez Benz C class', 'Mileage', 'Age(yrs)']

target = ['Sell Price($)']

# %%
# agora vou dividir os dados e aplicar o modelo de ML

X = df_new[features].values

y = df_new[target].values

# %%
X
# Out:
# array([[    0,     1,     0, 69000,     6],
#        [    0,     1,     0, 35000,     3],
#        [    0,     1,     0, 57000,     5],
#        [    0,     1,     0, 22500,     2],
#        [    0,     1,     0, 46000,     4],
#        [    1,     0,     0, 59000,     5],
#        [    1,     0,     0, 52000,     5],
#        [    1,     0,     0, 72000,     6],
#        [    1,     0,     0, 91000,     8],
#        [    0,     0,     1, 67000,     6],
#        [    0,     0,     1, 83000,     7],
#        [    0,     0,     1, 79000,     7],
#        [    0,     0,     1, 59000,     5]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=10)

# %%
X_test
# Out:
# array([[    0,     1,     0, 22500,     2],
#        [    1,     0,     0, 72000,     6],
#        [    0,     0,     1, 79000,     7],
#        [    1,     0,     0, 52000,     5]], dtype=int64)

# %%
# vou aplicar o modelo de Regressão linear

from sklearn.linear_model import LinearRegression

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(X_train, y_train.ravel())
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr_model.predict(X_test)
# Out:
# array([40759.91989318, 25418.50467291, 17956.58210947, 24802.42990655])

# %%
# respondendo Perguntas de negócio

# 1 prever o preço de um mercedez C class com 4 anos e 45000 de quilometragem

lr_model.predict([[0,0,1,45000,4]])
# Out:
# array([34778.37116154])

# %%
lr_model.predict([[0,1,0,86000,7]])
# Out:
# array([17630.46728973])

# %%
lr_model.score(X,y)
# Out:
# 0.8498848486865707
